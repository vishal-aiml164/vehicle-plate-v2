# %% [markdown]
# # In this Notebook we perform the following activities
#
# ### 1. Import the required Libraries
# ### 2. Extracting the Files from the path
# ### 3. Preparing the Dataframe for further processing

# %% [markdown]
# ### 1. Import the required Libraries

# %%
import pandas as pd
import xml.etree.ElementTree as xet
import os
from tqdm import tqdm

# %%
from glob import glob

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\anaconda3\\envs\\Python3715'

# %% [markdown]
# ### 2. Extracting the Files from the path

# %%
path=glob('C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\*.xml')

# %%
path
# Out:
# ['C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N1.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N100.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N101.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N102.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N103.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N104.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N105.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N106.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N107.xml',
#  'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N108.xml',
# ...

# %%
filename=path[0]
info=xet.parse(filename)
root=info.getroot()
member_object=root.find('object')
labels_info=member_object.find('bndbox')
xmin=int(labels_info.find('xmin').text)
xmax=int(labels_info.find('xmax').text)
ymin=int(labels_info.find('ymin').text)
ymax=int(labels_info.find('ymax').text)
print(xmin,xmax,ymin,ymax)
# Out:
# 1093 1396 645 727

# %%
labels_dict=dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in tqdm(path):
    #filename=path[0]
    info=xet.parse(filename)
    root=info.getroot()
    member_object=root.find('object')
    labels_info=member_object.find('bndbox')
    xmin=int(labels_info.find('xmin').text)
    xmax=int(labels_info.find('xmax').text)
    ymin=int(labels_info.find('ymin').text)
    ymax=int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)
# Out:
# 100%|██████████| 225/225 [00:00<00:00, 4423.73it/s]

# %%
labels_dict
# Out:
# {'filepath': ['C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N1.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N100.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N101.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N102.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N103.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N104.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N105.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N106.xml',
#   'C:\\Users\\DELL\\anaconda3\\CS_2\\vehicle_plate\\Project_Files\\1_Labeling\\images\\N107.xml',
# ...

# %% [markdown]
# ### 3. Preparing the Dataframe for further processing

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#                                               filepath  xmin  xmax  ymin  ymax
# 0    C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...  1093  1396   645   727
# 1    C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   134   301   312   350
# 2    C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...    31   139   128   161
# 3    C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   164   316   216   243
# 4    C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   813  1067   665   724
# ..                                                 ...   ...   ...   ...   ...
# 220  C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...    23   408   173   391
# 221  C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   137   352   141   186
# 222  C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   175   290   228   255
# 223  C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   563   675   207   238
# 224  C:\Users\DELL\anaconda3\CS_2\vehicle_plate\Pro...   158   389   129   193
#
# [225 rows x 5 columns]
